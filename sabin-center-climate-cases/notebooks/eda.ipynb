# %%
from artifacts import GLOBAL_LITIGATION_CASES_PATH, US_LITIGATION_CASES_PATH
import pandas as pd

# %%
global_cases = pd.read_csv(GLOBAL_LITIGATION_CASES_PATH, encoding='cp1252')
us_cases = pd.read_csv(US_LITIGATION_CASES_PATH, encoding='cp1252')

# %%
global_cases.to_csv("global_cases.csv", index=False)
us_cases.to_csv("us_cases.csv", index=False)

# %%
pd.read_csv("global_cases.csv")
pd.read_csv("us_cases.csv")
# Out:
#          ID                                          Case Name  Filing Year  \
# 0        22         TransCanada Keystone Pipeline, LP v. Kerry         2016
# 1        29                  Americans for Clean Energy v. EPA         2016
# 2        31                      WildEarth Guardians v. Jewell         2015
# 3        38  Center for Biological Diversity v. Federal Hig...         2016
# 4        41   Idaho Conservation League v. U.S. Forest Service         2016
# ...     ...                                                ...          ...
# 1704  42898    Green Oceans v. U.S. Department of the Interior         2024
# 1705  42901  Jurisich Oysters, LLC v. U.S. Army Corps of En...         2024
# 1706  42904  Association of Contracting Plumbers of the Cit...         2023
# 1707  42907  Sierra Club v. California Department of Water ...         2024
# 1708  42931  San Francisco Baykeeper v. California Departme...         2024
#
# ...
